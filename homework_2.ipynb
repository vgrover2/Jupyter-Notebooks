# %% [markdown]
# # Homework 2

# %% [markdown]
# ### Note

# %% [markdown]
# This homework will be focused on visualizing relationships between variables for plotting. It will provide a dataset, then ask to a question about the relationship between two variables. An example question might be
#
# > What statements are true about the relationship between variables A and B?
# >
# > 1. Higher A tends to mean higher B
# > 2. Lower A tends to mean higher B
# > 3. There's no clear relationship between A and B
# > 4. Every B variable is greater than 2
#
# The DataFrame that provides variables `A` and `B` will be provided, and will be encoded in a column of the DataFrame. Plotting variables `A` and `B` might yield
#
# <img src="./example.png" width="400px" />
#
# Statements (1) and (4) would be true given this plot.

# %% [markdown]
# ---

# %% [markdown]
# **Problem 1.**
# Use the code below to obtain the Flights data set. It contains information about distance traveled by the flights and delay in their arrival.
#
# ```python
# df = pd.read_csv("flights_20k.csv")
# ```
# You might observe that some flights have a negative delay. In this question, our objective is to analyze the relationship between the `distance` and `delay` variables for all flights that arrived early (i.e. **delay < 0**).
#
# Here is a hint:
# 1. Obtain a dataframe that contains all records with a negative delay (< 0).
# 2. Plot the `distance` and `delay` variables which represent the distance traveled by the flight and the delay in arrival to the destination.
#
# Which of the statements would hold for the plot obtained?
#
# A. There is a rough tendency that flights that travel a longer distance tend to arrive **later** (less negative delay).
#
# B. There is a rough tendency that flights that travel a longer distance tend to arrive **earlier** (more negative delay).
#
#
# <br>
#
# **`Gold-Star Question`**: Think about what kind of plot is apt for this data. Does switching the x-axis and y-axis variable affect your conclusion?

# %%
import pandas as pd
df = pd.read_csv("flights_20k.csv")
df
#df1.head(3)
# Out:
#                       date  delay destination  distance origin
# 0      2001-01-13 14:56:00     32         SJC       417    SAN
# 1      2001-01-31 16:40:00     -5         ISP      1093    FLL
# 2      2001-02-11 18:39:00      3         DAL       293    LBB
# 3      2001-01-10 21:00:00    -15         MCO       550    MSY
# 4      2001-03-30 21:45:00     -2         IND       229    STL
# ...                    ...    ...         ...       ...    ...
# 19995  2001-03-22 15:10:00      4         OAK       446    SAN
# 19996  2001-01-19 13:05:00     -6         MCI      1489    SEA
# 19997  2001-02-07 11:37:00    -16         PHX      1848    MCO
# 19998  2001-02-24 16:50:00     42         BNA       443    RDU
# 19999  2001-03-14 11:33:00      0         PHX       328    ABQ
#
# [20000 rows x 5 columns]

# %%
# your code here
import pandas as pd
df = pd.read_csv("flights_20k.csv")
df1 = df[df['delay'] > 0]
df2 = df[df['delay'] < 0]
#df2.head()
import matplotlib.pyplot as plt
# %matplotlib inline

# Positive delay plot
distance = df1['distance']
delay = df1['delay']

plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.scatter(distance, delay, alpha=0.5)  # alpha controls point transparency

plt.xlabel('Distance (miles)')
plt.ylabel('Delay (minutes)')
plt.title('Scatter Plot of Distance vs. Delay')

plt.grid(True)
plt.show()
import matplotlib.pyplot as plt2
# %matplotlib inline

# Negative delay plot
distance2 = df2['distance']
delay2 = df2['delay']

plt2.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt2.scatter(distance2, delay2, alpha=0.5)  # alpha controls point transparency

plt2.xlabel('Distance (miles)')
plt2.ylabel('Delay (minutes)')
plt2.title('Scatter Plot of Distance vs. Delay')

plt2.grid(True)
plt2.show()

# %% [markdown]
# ---

# %% [markdown]
# **Problem 2.** Consider the movies data set obtained from the code below. It contains various features of a movie, like its IMDB rating, Run-time, US Gross, Worldwide Gross, etc.
#
# ```python
# df2 = pd.read_csv("movies.csv")
# ```
# Which of the following claims are true about the data. Check all that apply
#
# **Options**
#
# A. Plotting a histogram of the Production Budget of **all** movies reveals a skewed right distribution. (Use `bins=15` while plotting) <br>
#
# B. A few movies that have a higher US Gross have a high IMDB Rating as well. But there are plenty of movies that have been rated high in IMDB without actually grossing a lot, so the trend is not very clear. <br>
#
# C. IMDB and Rotten Tomatoes ratings do not seem to have any relation between them <br>
#
# D. Most movies that have a higher Rotten Tomatoes rating tend to have a higher IMDB rating as well. <br>

# %%
# Given code
df3 = pd.read_csv("movies.csv")
df3.head(2)
# Out:
#   Creative_Type Director Distributor  IMDB_Rating  IMDB_Votes MPAA_Rating  \
# 0           NaN      NaN    Gramercy          6.1      1071.0           R
# 1           NaN      NaN      Strand          6.9       207.0           R
#
#   Major_Genre  Production_Budget Release_Date  Rotten_Tomatoes_Rating  \
# 0         NaN          8000000.0    12-Jun-98                     NaN
# 1       Drama           300000.0     7-Aug-98                     NaN
#
#    Running_Time_min Source                   Title  US_DVD_Sales  US_Gross  \
# 0               NaN    NaN          The Land Girls           NaN  146083.0
# 1               NaN    NaN  First Love, Last Rites           NaN   10876.0
#
#    Worldwide_Gross
# 0         146083.0
# 1          10876.0

# %%
# your code here
import matplotlib.pyplot as plt
# %matplotlib inline

budget = df3['Production_Budget']

plt.figure(figsize=(8, 5))  # Adjust the figure size as needed
plt.hist(budget, bins=15, color='skyblue', edgecolor='black')  # Adjust bins and colors

# Set labels and title
plt.xlabel('Production Budget')
plt.ylabel('Frequency')
plt.title('Histogram of Production Budget')

# Display the plot
plt.grid(True)
plt.show()

import matplotlib.pyplot as plt2 
# %matplotlib inline

imdb = df3['IMDB_Rating']
usGross = df3['US_Gross']

plt2.figure(figsize = (8, 5))
plt2.scatter(imdb, usGross, alpha = 0.5)

plt2.xlabel('IMDB Rating')
plt2.ylabel('US_Gross')
plt2.title('Scatter of IMDB vs Gross')

plt2.grid(True)
plt2.show

import matplotlib.pyplot as plt3
# %matplotlib inline
rottenTomatoes = df3['Rotten_Tomatoes_Rating']

plt3.figure(figsize = (8,5))
plt3.scatter(imdb, rottenTomatoes, alpha = 0.5)

plt3.xlabel('IMDB Rating')
plt3.ylabel('Rotten Tomatoes Rating')
plt3.title('IMDB vs Rotten Tomatoes')

plt3.grid(True)
plt3.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ---

# %% [markdown]
# **Problem 3.** Consider the Gapminder data set obtained from the code below. It contains information such as life expectancy, fertility rate (Children per woman), population etc. about countries over the years.
# ```python
# df3 = pd.read_csv("gapminder.csv")
# ```
# Which of the following is True?
#
# **Options**
#
# A - Life expectancy and fertility have a positive trend between them. This means that as as one increases, the other tends to increase too.
#
# B - Life expectancy and fertility have a negative trend between them. This means that as one increases, the other tends to decrease.
#
# C - Plot the population of Rwanda over the years. There is a sudden dip in the population of Rwanda around mid 1990's.
#
# D - Plot the population of Kenya over the years. There is a sudden dip in the population of Kenya around mid 1990's.
#
# **`Gold-Star Question`**:  At-least one of the observations about Kenya and Rwanda is true. What unfortunate event could have caused this?

# %%
# given code
df4 = pd.read_csv("gapminder.csv")
df4.head()
# Out:
#    cluster      country  fertility  life_expect       pop  year
# 0        0  Afghanistan        7.7       30.332   8891209  1955
# 1        0  Afghanistan        7.7       31.997   9829450  1960
# 2        0  Afghanistan        7.7       34.020  10997885  1965
# 3        0  Afghanistan        7.7       36.088  12430623  1970
# 4        0  Afghanistan        7.7       38.438  14132019  1975

# %%
# your code here
df4 = pd.read_csv("gapminder.csv")

import matplotlib.pyplot as plt4
# %matplotlib inline

lifeExpectancy = df4['life_expect']
fertility = df4['fertility']

plt4.figure(figsize = (8,5))
plt4.scatter(lifeExpectancy, fertility, alpha = 0.5)

plt4.xlabel('Life Expectancy')
plt4.ylabel('Fertility')
plt4.title('Life Expectancy vs Fertility')

plt4.grid(True)
plt4.show()

import matplotlib.pyplot as plt5
# %matplotlib inline
df5 = df4[df4['country'] == 'Rwanda']
df5

year = df5['year']
population = df5['pop']

plt5.figure(figsize = (8, 5))
plt5.scatter(year, population, alpha = 0.5)

plt5.xlabel('Year')
plt5.ylabel('Population')
plt5.title('Population of Rwanda over time')

plt5.grid(True)
plt5.show()

import matplotlib.pyplot as plt6
# %matplotlib inline
df6 = df4[df4['country'] == 'Kenya']
df6

year = df6['year']
population = df6['pop']

plt6.figure(figsize = (8, 5))
plt6.scatter(year, population, alpha = 0.5)

plt6.xlabel('Year')
plt6.ylabel('Population')
plt6.title('Population of Kenya over time')

plt6.grid(True)
plt6.show()

# %% [markdown]
# ---
# **Problem 4.**
# Consider the cars data set imported using the code below, containing information about different cars built over the years.
# ```python
# df4 = pd.read_csv("cars.csv")
# ```
# What inference can you derive from the data?
#
# **Options**
#
# A - Cars with higher Horsepower tend to have higher Displacement.
#
# B - Cars with lower Horsepower tend to have higher Displacement.
#
# C - Heavier cars tend to have a lower Mileage (Miles_per_Gallon)
#
# D - Cars with more cylinders tend to have lower horsepower

# %%
# given code
dfc = pd.read_csv("cars.csv")
dfc.head()
# Out:
#    Unnamed: 0  Acceleration  Cylinders  Displacement  Horsepower  \
# 0           0          12.0          8         307.0       130.0
# 1           1          11.5          8         350.0       165.0
# 2           2          11.0          8         318.0       150.0
# 3           3          12.0          8         304.0       150.0
# 4           4          10.5          8         302.0       140.0
#
#    Miles_per_Gallon                       Name Origin  Weight_in_lbs  \
# 0              18.0  chevrolet chevelle malibu    USA           3504
# 1              15.0          buick skylark 320    USA           3693
# 2              18.0         plymouth satellite    USA           3436
# 3              16.0              amc rebel sst    USA           3433
# 4              17.0                ford torino    USA           3449
#
#          Year
# 0  1970-01-01
# 1  1970-01-01
# 2  1970-01-01
# 3  1970-01-01
# 4  1970-01-01

# %%
# your code here
dfc = pd.read_csv("cars.csv")

import matplotlib.pyplot as pltc
# %matplotlib inline

hp = dfc['Horsepower']
disp = dfc['Displacement']

pltc.figure(figsize = (8,5))
pltc.scatter(hp, disp, alpha = 0.5)

pltc.xlabel('Horsepower')
pltc.ylabel('Displacement')
pltc.title('Horsepower vs Displacement')

pltc.grid(True)
pltc.show()

import matplotlib.pyplot as pltc2
# %matplotlib inline

weight = dfc['Weight_in_lbs']
mileage = dfc['Miles_per_Gallon']

pltc2.figure(figsize = (8,5))
pltc2.scatter(weight, mileage, alpha = 0.5)

pltc2.xlabel('Weight')
pltc2.ylabel('Mileage')
pltc2.title('Weight vs Mileage')

pltc2.grid(True)
pltc2.show()

import matplotlib.pyplot as pltc3
# %matplotlib inline

hp = dfc['Horsepower']
cyl = dfc['Cylinders']

pltc3.figure(figsize = (8,5))
pltc3.scatter(hp, cyl, alpha = 0.5)

pltc3.xlabel('Horsepower')
pltc3.ylabel('Cylinders')
pltc3.title('Horsepower vs Cylinders')

pltc3.grid(True)
pltc3.show()

# %% [markdown]
# ---
# **Problem 5.** Consider the Stocks data imported from the code below. It shows monthly prices of 5 companies over time.
# ```python
# df5 = pd.read_csv("stocks.csv")
# ```
# Which of the following statements are true about the data -
#
# Hints:
#
# To get more ticks in the x axis than default, you can use the following code. We an decrease/increase the step value to get more/less granular x-ticks respectively. (We are taking the range between 0-124 because we only have 123 data points)
# ```python
# ax.set_xticks(range(0, 124, 5));
# ```
# You will not be able to get dates in the x-ticks , but you can find the date for a particular index by pandas indexing.
#
# **Options**
#
# A - There is an overall **decrease** in all stock prices in the dataframe index range 100 - 110.
#
# B - There is an overall **decrease** in all stock prices between dates May-2008 to March-2009.
#
# C - All stock prices fall in the in the dataframe index range 55- 60.
#
# D - In a line plot, Google has no price until index 55 because values before index 55 are zero.
#
# E - In a line plot, Google has no price until index 55 because values before index 55 are nan.

# %%
# given code
dfs = pd.read_csv("stocks.csv")
#dfs.head(3)
stock_slice = dfs.iloc[100:111]
stock_slice
# Out:
#           date  Apple  Amazon  Google     IBM  Microsoft
# 0   2000-01-01  25.94   64.56     NaN  100.52      39.81
# 1   2000-02-01  28.66   68.87     NaN   92.11      36.35
# 2   2000-03-01  33.95   67.00     NaN  106.11      43.22
# 3   2000-04-01  31.01   55.19     NaN   99.95      28.37
# 4   2000-05-01  21.00   48.31     NaN   96.31      25.45
# 5   2000-06-01  26.19   36.31     NaN   98.33      32.54
# 6   2000-07-01  25.41   30.12     NaN  100.74      28.40
# 54  2004-07-01  16.17   38.92     NaN   80.19      23.38

# %%
# your code here
dfs = pd.read_csv("stocks.csv")

import matplotlib.pyplot as plts
# %matplotlib inline

stock_slice = dfs.iloc[100:111]
date = stock_slice['date']
apple = stock_slice['Apple'] 
amazon = stock_slice['Amazon'] 
google = stock_slice['Google'] 
ibm = stock_slice['IBM'] 
microsoft = stock_slice['Microsoft'] 

plts.figure(figsize = (15,5))
plts.scatter(date, apple, alpha = 0.5)
plts.scatter(date, amazon, alpha = 0.5)
plts.scatter(date, google, alpha = 0.5)
plts.scatter(date, ibm, alpha = 0.5)
plts.scatter(date, microsoft, alpha = 0.5)

plts.xlabel('Date')
plts.ylabel('Price')
plts.title('Price vs Date')

plts.grid(True)
plts.show()

import matplotlib.pyplot as plts2
# %matplotlib inline

date_slice = dfs[(dfs['date'] >= '2008-05') & (dfs['date'] <= '2009-04')]
date = date_slice['date']
apple = date_slice['Apple'] 
amazon = date_slice['Amazon'] 
google = date_slice['Google'] 
ibm = date_slice['IBM'] 
microsoft = date_slice['Microsoft'] 

plts2.figure(figsize = (16,6))
plts2.scatter(date, apple, alpha = 0.5)
plts2.scatter(date, amazon, alpha = 0.5)
plts2.scatter(date, google, alpha = 0.5)
plts2.scatter(date, ibm, alpha = 0.5)
plts2.scatter(date, microsoft, alpha = 0.5)

plts2.xlabel('Date')
plts2.ylabel('Price')
plts2.title('Price 2 vs Date 2')

plts2.grid(True)
plts2.show()

import matplotlib.pyplot as plts3
# %matplotlib inline

stock_slice = dfs.iloc[55:60]
date = stock_slice['date']
apple = stock_slice['Apple'] 
amazon = stock_slice['Amazon'] 
google = stock_slice['Google'] 
ibm = stock_slice['IBM'] 
microsoft = stock_slice['Microsoft'] 

plts3.figure(figsize = (15,5))
plts3.scatter(date, apple, alpha = 0.5)
plts3.scatter(date, amazon, alpha = 0.5)
plts3.scatter(date, google, alpha = 0.5)
plts3.scatter(date, ibm, alpha = 0.5)
plts3.scatter(date, microsoft, alpha = 0.5)

plts3.xlabel('Date')
plts3.ylabel('Price')
plts3.title('Price 3 vs Date 3')

plts.grid(True)
plts.show()

stock_slice2 = dfs.iloc[0:56]
stock_slice2
# Out:
#           date  Apple  Amazon  Google     IBM  Microsoft
# 0   2000-01-01  25.94   64.56     NaN  100.52      39.81
# 1   2000-02-01  28.66   68.87     NaN   92.11      36.35
# 2   2000-03-01  33.95   67.00     NaN  106.11      43.22
# 3   2000-04-01  31.01   55.19     NaN   99.95      28.37
# 4   2000-05-01  21.00   48.31     NaN   96.31      25.45
# 5   2000-06-01  26.19   36.31     NaN   98.33      32.54
# 6   2000-07-01  25.41   30.12     NaN  100.74      28.40
# 7   2000-08-01  30.47   41.50     NaN  118.62      28.40
# 8   2000-09-01  12.88   38.44     NaN  101.19      24.53
# 9   2000-10-01   9.78   36.62     NaN   88.50      28.02
